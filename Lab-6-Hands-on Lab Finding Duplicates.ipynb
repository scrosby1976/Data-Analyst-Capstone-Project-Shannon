# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Finding Duplicates Lab**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# ## Introduction

# %% [markdown]
# Data wrangling is a critical step in preparing datasets for analysis, and handling duplicates plays a key role in ensuring data accuracy. In this lab, you will focus on identifying and removing duplicate entries from your dataset.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab, you will perform the following:

# %% [markdown]
# 1. Identify duplicate rows in the dataset and analyze their characteristics.
# 2. Visualize the distribution of duplicates based on key attributes.
# 3. Remove duplicate values strategically based on specific criteria.
# 4. Outline the process of verifying and documenting duplicate removal.

# %% [markdown]
# ## Hands on Lab

# %% [markdown]
# Install the needed library

# %%
# !pip install pandas
# !pip install matplotlib

# %% [markdown]
# Import pandas module

# %%
import pandas as pd

# %% [markdown]
# Import matplotlib

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## **Load the dataset into a dataframe**

# %% [markdown]
# <h2>Read Data</h2>
# <p>
# We utilize the <code>pandas.read_csv()</code> function for reading CSV files. However, in this version of the lab, which operates on JupyterLite, the dataset needs to be downloaded to the interface using the provided code below.
# </p>

# %%
# Load the dataset directly from the URL
file_path = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/VYPrOu0Vs3I0hKLLjiPGrA/survey-data-with-duplicate.csv"
df = pd.read_csv(file_path)

# Display the first few rows
df.head()
# Out:
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# 3           4           I am learning to code     18-24 years old
# 4           5  I am a developer by profession     18-24 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 2  Employed, full-time     Remote  Apples
# 3   Student, full-time        NaN  Apples
# 4   Student, full-time        NaN  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# 2  Hobby;Contribute to open-source projects;Other...
# 3                                                NaN
# ...

# %% [markdown]
# Load the data into a pandas dataframe:

# %% [markdown]
# Note: If you are working on a local Jupyter environment, you can use the URL directly in the pandas.read_csv() function as shown below:

# %%
#df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv")

# %% [markdown]
# ## Identify and Analyze Duplicates

# %% [markdown]
# ### Task 1: Identify Duplicate Rows
# 1. Count the number of duplicate rows in the dataset.
# 2. Display the first few duplicate rows to understand their structure.

# %%
num_duplicates = df.duplicated(
    subset=df.columns.difference(["ResponseId"])
).sum()

num_duplicates
# Out:
# np.int64(507)

# %%
duplicates = df[df.duplicated(
    subset=df.columns.difference(["ResponseId"]),
    keep=False
)]

duplicates.head()
# Out:
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# 3           4           I am learning to code     18-24 years old
# 4           5  I am a developer by profession     18-24 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 2  Employed, full-time     Remote  Apples
# 3   Student, full-time        NaN  Apples
# 4   Student, full-time        NaN  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# 2  Hobby;Contribute to open-source projects;Other...
# 3                                                NaN
# ...

# %% [markdown]
# ### Task 2: Analyze Characteristics of Duplicates
# 1. Identify duplicate rows based on selected columns such as MainBranch, Employment, and RemoteWork. Analyse which columns frequently contain identical values within these duplicate rows.
# 2. Analyse the characteristics of rows that are duplicates based on a subset of columns, such as MainBranch, Employment, and RemoteWork. Determine which columns frequently have identical values across these rows.

# %%
#define the subset
subset_cols = ["MainBranch", "Employment", "RemoteWork"]

# %%
#identify rows that are duplicated
duplicates_subset = df[df.duplicated(
    subset=subset_cols,
    keep=False
)]

# %%
#group the data
grouped = duplicates_subset.groupby(subset_cols)

# %%
identical_summary = {}

for col in df.columns:
    if col in subset_cols:
        continue  # skip defining columns
    
    identical_summary[col] = grouped[col].nunique().eq(1).sum()

identical_summary_df = (
    pd.Series(identical_summary)
    .sort_values(ascending=False)
)

identical_summary_df.head(10)
# Out:
# Check                         319
# ICorPM                         97
# AIThreat                       88
# SOAccount                      85
# AINextLess integrated          76
# SurveyLength                   75
# AISelect                       75
# AINextMuch more integrated     74
# SOPartFreq                     67
# AINextNo change                67
# dtype: int64

# %% [markdown]
# ### Task 3: Visualize Duplicates Distribution
# 1. Create visualizations to show the distribution of duplicates across different categories.
# 2. Use bar charts or pie charts to represent the distribution of duplicates by Country and Employment.

# %%
duplicates = df[df.duplicated(
    subset=df.columns.difference(["ResponseId"]),
    keep=False
)]

# %%
dup_country_counts = duplicates["Country"].value_counts().head(10)
dup_country_counts
# Out:
# Country
# United States of America                                8
# United Kingdom of Great Britain and Northern Ireland    6
# Canada                                                  4
# Germany                                                 4
# Norway                                                  2
# Uzbekistan                                              2
# Nigeria                                                 2
# Serbia                                                  2
# Iran, Islamic Republic of...                            2
# India                                                   2
# Name: count, dtype: int64

# %%
dup_country_counts.plot(kind="bar", figsize=(10, 5))
plt.title("Distribution of Duplicate Responses by Country")
plt.xlabel("Country")
plt.ylabel("Number of Duplicate Rows")
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()

# %%
dup_employment_counts = duplicates["Employment"].value_counts()
dup_employment_counts
# Out:
# Employment
# Employed, full-time                                                         458
# Student, full-time                                                           75
# Independent contractor, freelancer, or self-employed                         37
# Not employed, but looking for work                                           17
# Employed, full-time;Independent contractor, freelancer, or self-employed     16
# I prefer not to say                                                          14
# Student, full-time;Employed, part-time                                        8
# Employed, full-time;Student, full-time                                        8
# Student, full-time;Not employed, but looking for work                         7
# Student, part-time                                                            6
# Not employed, and not looking for work                                        5
# Employed, part-time                                                           4
# ...

# %%
dup_employment_counts.plot(kind="bar", figsize=(10, 8))
plt.title("Distribution of Duplicate Responses by Employment Status")
plt.xlabel("Employment")
plt.ylabel("Number of Duplicate Rows")
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Task 4: Strategic Removal of Duplicates
# 1. Decide which columns are critical for defining uniqueness in the dataset.
# 2. Remove duplicates based on a subset of columns if complete row duplication is not a good criterion.

# %%
unique_cols = [
    "MainBranch",
    "Employment",
    "RemoteWork",
    "Country",
    "Age"
]
df_deduped = df.drop_duplicates(
    subset=unique_cols,
    keep="first"
)

# %% [markdown]
# ## Verify and Document Duplicate Removal Process

# %% [markdown]
# ### Task 5: Documentation
# 1. Document the process of identifying and removing duplicates.

# %% [raw]
# Step 1: Check for “unique identifier” columns that prevent duplicate detection.
# Start by looking for columns like ResponseId that are unique in every row. If a column is completely unique, full-row duplicate checks may show zero duplicates even when the response content is repeated.
#
# Step 2: Review columns that repeat heavily and decide whether they should be used for uniqueness.
# Scan for columns with high repetition (for example, SurveyLength). These fields may not help define a unique response because they don’t distinguish records well.
#
# Step 3: Select a subset of “core” columns that represent meaningful respondent attributes.
# Choose columns that describe the respondent in a meaningful way (e.g., MainBranch, Employment, RemoteWork, Country, Age) and are appropriate for defining uniqueness.
#
# Step 4: Validate the chosen columns using simple visual checks.
# Use visualizations (like bar charts) to confirm distributions and spot any odd patterns before using these columns as your duplicate criteria.
#
# Step 5: Remove duplicates using only the selected core columns.
# Drop duplicates based on the chosen subset (not the full row), so you remove repeated respondent profiles without being blocked by unique IDs.

# %% [markdown]
# 2. Explain the reasoning behind selecting specific columns for identifying and removing duplicates.

# %% [raw]
# During the initial duplicate count, I observed that the ResponseId column was unique for every row, which resulted in no duplicate rows when considering the full dataset. To better understand where duplication actually existed, I excluded ResponseId from the duplicate detection process and re-ran the analysis.
#
# Next, I examined duplication across individual columns to identify which fields were overly repetitive and therefore unsuitable for defining uniqueness. Columns that exhibited excessive repetition or provided limited distinguishing power were not considered appropriate identifiers for duplicate detection.
#
# Based on this analysis, I determined that MainBranch, Employment, RemoteWork, Country, and Age represented meaningful respondent characteristics and provided a reasonable balance between uniqueness and interpretability. These columns were selected as the defining subset for identifying and removing duplicate rows in the dataset.

# %% [markdown]
# ### Summary and Next Steps
# **In this lab, you focused on identifying and analyzing duplicate rows within the dataset.**
#
# - You employed various techniques to explore the nature of duplicates and applied strategic methods for their removal.
# - For additional analysis, consider investigating the impact of duplicates on specific analyses and how their removal affects the results.
# - This version of the lab is more focused on duplicate analysis and handling, providing a structured approach to deal with duplicates in a dataset effectively.

# %% [markdown]
# <!--
# ## Change Log
# |Date (YYYY-MM-DD)|Version|Changed By|Change Description|
# |-|-|-|-|
# |2024-11- 05|1.3|Madhusudhan Moole|Updated lab|
# |2024-10-28|1.2|Madhusudhan Moole|Updated lab|
# |2024-09-24|1.1|Madhusudhan Moole|Updated lab|
# |2024-09-23|1.0|Raghul Ramesh|Created lab|
# --!>

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.
